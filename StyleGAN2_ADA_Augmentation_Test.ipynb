# %% [markdown]
# <a href="https://colab.research.google.com/github/robgon-art/MachineRay2/blob/main/StyleGAN2_ADA_Augmentation_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/robgon-art/stylegan2-ada
# %tensorflow_version 1.x
# !pip show tensorflow
# Out:
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 69 (delta 0), reused 0 (delta 0), pack-reused 65
# Unpacking objects: 100% (69/69), done.
# TensorFlow 1.x selected.
# Name: tensorflow
# Version: 1.15.2
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /tensorflow-1.15.2/python3.6
# Requires: six, wheel, termcolor, tensorflow-estimator, opt-einsum, keras-applications, keras-preprocessing, protobuf, tensorboard, wrapt, grpcio, astor, absl-py, google-pasta, numpy, gast
# Required-by: stable-baselines, magenta, fancyimpute

# %%
# !wget https://raw.githubusercontent.com/robgon-art/MachineRay2/main/SampleImage.png
# Out:
# --2020-12-22 20:46:12--  https://raw.githubusercontent.com/robgon-art/MachineRay2/main/SampleImage.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61678 (60K) [image/png]
# Saving to: ‘SampleImage.png’
#
# SampleImage.png     100%[===================>]  60.23K  --.-KB/s    in 0.01s
#
# 2020-12-22 20:46:13 (4.40 MB/s) - ‘SampleImage.png’ saved [61678/61678]

# %%
# !mkdir samples
# !mkdir dataset
# !mkdir output
# !cp SampleImage.png samples/

# %%
# !python stylegan2-ada/dataset_tool.py create_from_images 'dataset' 'samples'
# Out:
# Loading images from "samples"
# Creating dataset "dataset"
# Added 1 images.

# %%
# !python stylegan2-ada/train.py --gpus=1 --aug=fixed --p=0.4 --data=dataset --outdir=output --snap=1 --kimg=4 --metrics=none
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x86a4000 @  0x7ff9e7e4c001 0x7ff9e508f4ff 0x7ff9e50dfab8 0x7ff9e50e3bb7 0x7ff9e5182003 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7ff80c2c2000 @  0x7ff9e7e4a1e7 0x7ff9e508f41e 0x7ff9e50dfbdb 0x7ff9e50e02bf 0x7ff9e5181f03 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# ...

# %%
from PIL import Image
image = Image.open('/content/output/00000-dataset-auto1-kimg4-fixed-p0.4/reals.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x512 at 0x7F7FA7555C50>
